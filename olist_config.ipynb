# %% [markdown]
# <a href="https://colab.research.google.com/github/vshnuvrdhan/financial-ops-olist-analytics/blob/main/olist_config.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configuration file for Olist Analytics Project

# Database Configuration
DB_CONFIG = {
    'host': 'localhost',
    'port': 5432,
    'user': 'postgres',
    'password': 'vishnu007',
    'database': 'olist_analytics',
}

# API Configuration
API_CONFIG = {
    'exchange_rates_url': 'https://open.er-api.com/v6/latest/USD',
    'timeout': 10,
    'base_currency': 'USD',
    'target_currencies': ['BRL', 'EUR', 'GBP', 'USD'],
}

# File Paths
DATA_PATHS = {
    'orders': 'olist_orders_dataset.csv',
    'customers': 'olist_customers_dataset.csv',
    'sellers': 'olist_sellers_dataset.csv',
    'order_items': 'olist_order_items_dataset.csv',
    'order_payments': 'olist_order_payments_dataset.csv',
    'order_reviews': 'olist_order_reviews_dataset.csv',
    'products': 'olist_products_dataset.csv',
    'geolocation': 'olist_geolocation_dataset.csv',
}

# Table Mappings (CSV columns → Database columns)
COLUMN_MAPPING = {
    'orders': {
        'order_id': 'order_id',
        'customer_id': 'customer_id',
        'order_status': 'order_status',
        'order_purchase_timestamp': 'order_purchase_timestamp',
        'order_approved_at': 'order_approved_at',
        'order_delivered_carrier_date': 'order_delivered_carrier_date',
        'order_delivered_customer_date': 'order_delivered_customer_date',
        'order_estimated_delivery_date': 'order_estimated_delivery_date',
    },
    'customers': {
        'customer_id': 'customer_id',
        'customer_zip_code_prefix': 'customer_zip_code_prefix',
        'customer_city': 'customer_city',
        'customer_state': 'customer_state',
    },
    'sellers': {
        'seller_id': 'seller_id',
        'seller_zip_code_prefix': 'seller_zip_code_prefix',
        'seller_city': 'seller_city',
        'seller_state': 'seller_state',
    },
}

print("✓ Configuration loaded successfully")
# Out:
# ✓ Configuration loaded successfully
